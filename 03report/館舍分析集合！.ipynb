# %%
import pipeline

# %matplotlib inline
# %pylab inline

#plot setting
plt.style.use('ggplot')
pylab.rcParams['figure.figsize'] = (20, 8)

# %%
### Input data ###
Path = "../01data/106B_P1_P4/+teach_p2.csv"
Period = 1 
Rate = 2.45
### Input data ###

# %%
def plot_weekday(df):
    df.groupby(['Weekday','Week']).Cost.sum().unstack().plot.bar(legend = True)
    plt.title('{}: Cost Sum, by Weekdays'.format(Place), fontsize = 20)


def plot_hour(df):
    df.groupby(['Time','Weekday']).Cost.sum().unstack().plot(legend = True)
    plt.title('{}: Cost Sum, by Hours'.format(Place), fontsize = 20)

# %%
Place = "EB3"
pipeline.analysis(Path,Place, Rate)

df = pipeline.make_df(Path, Place, Rate)
df = pipeline.generate_cost_columns(df,Rate)
# Out:
#        Unnamed: 0          DateTime Area Building  Loop Type  Usage  \
# 12600       12600  2018/03/12 00:00    S      EB3  main  edu  186.0
# 12601       12601  2018/03/12 01:00    S      EB3  main  edu  180.0
# 12602       12602  2018/03/12 02:00    S      EB3  main  edu  178.0
# 12603       12603  2018/03/12 03:00    S      EB3  main  edu  174.0
# 12604       12604  2018/03/12 04:00    S      EB3  main  edu  174.0
#
#              Date  Weekday DayName   Time  Week
# 12600  2018-03-12        1  Monday  00:00    11
# 12601  2018-03-12        1  Monday  01:00    11
# 12602  2018-03-12        1  Monday  02:00    11
# 12603  2018-03-12        1  Monday  03:00    11
# 12604  2018-03-12        1  Monday  04:00    11
# Column "Cost" had been generated!
# 2018-04-12    4
# 2018-04-13    3
# 2018-04-02    3
# Name: Date, dtype: int64
# 14:00    3
# 15:00    3
# 13:00    3
# 16:00    1
# Name: Time, dtype: int64
# 926.1    2
# 921.2    2
# 960.4    1
# 980.0    1
# 950.6    1
# 999.6    1
# ...

# %%
Place = "SB2"
pipeline.analysis(Path,Place, Rate)

df = pipeline.make_df(Path, Place, Rate)
df = pipeline.generate_cost_columns(df,Rate)
# Out:
#       Unnamed: 0          DateTime Area Building  Loop Type  Usage  \
# 8400        8400  2018/03/12 00:00    N      SB2  main  edu  141.0
# 8401        8401  2018/03/12 01:00    N      SB2  main  edu  136.0
# 8402        8402  2018/03/12 02:00    N      SB2  main  edu  132.0
# 8403        8403  2018/03/12 03:00    N      SB2  main  edu  130.0
# 8404        8404  2018/03/12 04:00    N      SB2  main  edu  130.0
#
#             Date  Weekday DayName   Time  Week
# 8400  2018-03-12        1  Monday  00:00    11
# 8401  2018-03-12        1  Monday  01:00    11
# 8402  2018-03-12        1  Monday  02:00    11
# 8403  2018-03-12        1  Monday  03:00    11
# 8404  2018-03-12        1  Monday  04:00    11
# Column "Cost" had been generated!
# 2018-04-12    4
# 2018-04-02    2
# 2018-03-29    2
# 2018-04-03    2
# Name: Date, dtype: int64
# 14:00    4
# 15:00    3
# 13:00    2
# 16:00    1
# Name: Time, dtype: int64
# 588.00    2
# 592.90    1
# 614.95    1
# 644.35    1
# 605.15    1
# ...

# %%
Place = "SB3"
pipeline.analysis(Path,Place, Rate)

df = pipeline.make_df(Path, Place, Rate)
df = pipeline.generate_cost_columns(df,Rate)
# Out:
#       Unnamed: 0          DateTime Area Building  Loop Type  Usage  \
# 6720        6720  2018/03/12 00:00    N      SB3  main  edu  279.0
# 6721        6721  2018/03/12 01:00    N      SB3  main  edu  277.0
# 6722        6722  2018/03/12 02:00    N      SB3  main  edu  272.0
# 6723        6723  2018/03/12 03:00    N      SB3  main  edu  278.0
# 6724        6724  2018/03/12 04:00    N      SB3  main  edu  284.0
#
#             Date  Weekday DayName   Time  Week
# 6720  2018-03-12        1  Monday  00:00    11
# 6721  2018-03-12        1  Monday  01:00    11
# 6722  2018-03-12        1  Monday  02:00    11
# 6723  2018-03-12        1  Monday  03:00    11
# 6724  2018-03-12        1  Monday  04:00    11
# Column "Cost" had been generated!
# 2018-04-13    6
# 2018-04-12    4
# Name: Date, dtype: int64
# 15:00    2
# 14:00    2
# 13:00    2
# 10:00    1
# 11:00    1
# 12:00    1
# 16:00    1
# Name: Time, dtype: int64
# 1291.15    2
# 1342.60    1
# 1296.05    1
# 1239.70    1
# ...

# %%
Place = "EB3"
pipeline.analysis(Path,Place, Rate)

df = pipeline.make_df(Path, Place, Rate)
df = pipeline.generate_cost_columns(df,Rate)
# Out:
#        Unnamed: 0          DateTime Area Building  Loop Type  Usage  \
# 12600       12600  2018/03/12 00:00    S      EB3  main  edu  186.0
# 12601       12601  2018/03/12 01:00    S      EB3  main  edu  180.0
# 12602       12602  2018/03/12 02:00    S      EB3  main  edu  178.0
# 12603       12603  2018/03/12 03:00    S      EB3  main  edu  174.0
# 12604       12604  2018/03/12 04:00    S      EB3  main  edu  174.0
#
#              Date  Weekday DayName   Time  Week
# 12600  2018-03-12        1  Monday  00:00    11
# 12601  2018-03-12        1  Monday  01:00    11
# 12602  2018-03-12        1  Monday  02:00    11
# 12603  2018-03-12        1  Monday  03:00    11
# 12604  2018-03-12        1  Monday  04:00    11
# Column "Cost" had been generated!
# 2018-04-12    4
# 2018-04-13    3
# 2018-04-02    3
# Name: Date, dtype: int64
# 14:00    3
# 15:00    3
# 13:00    3
# 16:00    1
# Name: Time, dtype: int64
# 926.1    2
# 921.2    2
# 960.4    1
# 980.0    1
# 950.6    1
# 999.6    1
# ...

# %%
Place = "EB4"
pipeline.analysis(Path,Place, Rate)

df = pipeline.make_df(Path, Place, Rate)
df = pipeline.generate_cost_columns(df,Rate)
# Out:
#        Unnamed: 0          DateTime Area Building  Loop Type  Usage  \
# 13440       13440  2018/03/12 00:00    S      EB4  main  edu  264.0
# 13441       13441  2018/03/12 01:00    S      EB4  main  edu  246.0
# 13442       13442  2018/03/12 02:00    S      EB4  main  edu  242.0
# 13443       13443  2018/03/12 03:00    S      EB4  main  edu  234.0
# 13444       13444  2018/03/12 04:00    S      EB4  main  edu  236.0
#
#              Date  Weekday DayName   Time  Week
# 13440  2018-03-12        1  Monday  00:00    11
# 13441  2018-03-12        1  Monday  01:00    11
# 13442  2018-03-12        1  Monday  02:00    11
# 13443  2018-03-12        1  Monday  03:00    11
# 13444  2018-03-12        1  Monday  04:00    11
# Column "Cost" had been generated!
# 2018-04-13    4
# 2018-04-12    4
# 2018-04-02    2
# Name: Date, dtype: int64
# 14:00    3
# 15:00    3
# 16:00    2
# 13:00    2
# Name: Time, dtype: int64
# 1445.5    2
# 1421.0    2
# 1372.0    2
# 1406.3    1
# 1425.9    1
# ...

# %%
Place = "EB5"
pipeline.analysis(Path,Place, Rate)

df = pipeline.make_df(Path, Place, Rate)
df = pipeline.generate_cost_columns(df,Rate)
# Out:
#        Unnamed: 0          DateTime Area Building  Loop Type  Usage  \
# 14280       14280  2018/03/12 00:00    S      EB5  main  edu  197.5
# 14281       14281  2018/03/12 01:00    S      EB5  main  edu  183.0
# 14282       14282  2018/03/12 02:00    S      EB5  main  edu  177.0
# 14283       14283  2018/03/12 03:00    S      EB5  main  edu  170.5
# 14284       14284  2018/03/12 04:00    S      EB5  main  edu  163.0
#
#              Date  Weekday DayName   Time  Week
# 14280  2018-03-12        1  Monday  00:00    11
# 14281  2018-03-12        1  Monday  01:00    11
# 14282  2018-03-12        1  Monday  02:00    11
# 14283  2018-03-12        1  Monday  03:00    11
# 14284  2018-03-12        1  Monday  04:00    11
# Column "Cost" had been generated!
# 2018-04-12    4
# 2018-04-13    3
# 2018-04-02    1
# 2018-04-11    1
# 2018-04-03    1
# Name: Date, dtype: int64
# 14:00    4
# 15:00    2
# 13:00    2
# 12:00    1
# 16:00    1
# Name: Time, dtype: int64
# 1347.500    3
# ...
